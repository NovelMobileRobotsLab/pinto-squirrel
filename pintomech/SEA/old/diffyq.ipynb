# %%
from sympy import *
from sympy.solvers.ode.systems import dsolve_system
x, y = symbols("x y", cls=Function)
t = symbols("t")

k = symbols('k')

T1 = 0.00025 #0.035 m / 140 rad from TSA test
# T1 = symbols("T1") #0.035 m / 140 rad from TSA test
T2 = 3 #guess for leg movement/string contract
m_a = 1/2 * 0.020 * 0.010**2 #cylinder MOI 20g 10mm radius
m_l = 0.1 #mass to push off ground
k = 1000 # no idea honestly

tau_s = 0.1 #N*m stall torque
omega_f = 3000 #about 10,000rpm free speed

eqs = [
    Eq(x(t).diff(t).diff(t), -(T1**2*k/m_a)*x(t) - (T1*k/(T2*m_a))*y(t) + (tau_s - tau_s*x.diff(t)/omega_f)/m_a), 
    Eq(y(t).diff(t).diff(t), (k*T1/(T2*m_l))*x(t) - (k/(T2**2*m_l))*y(t))
]
display(eqs[0], eqs[1])

sol = dsolve_system(eqs, ics={x(0):0, y(0):0, x(t).diff(t).subs(t,0):0, y(t).diff(t).subs(t,0):0})
# sol = dsolve_system(eqs)

xeq = simplify(sol[0][0])
yeq = simplify(sol[0][1])
display(xeq, yeq)
# Out:
# Eq(Derivative(x(t), (t, 2)), -62.5*x(t) - 83333.3333333333*y(t) + 99966.6666666667)
# Eq(Derivative(y(t), (t, 2)), 0.833333333333333*x(t) - 1111.11111111111*y(t))
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/simplify/radsimp.py:1131: SymPyDeprecationWarning:
#
# Using non-Expr arguments in Mul is deprecated (in this case, one of
# the arguments has type 'Tuple').
#
# If you really did intend to use a multiplication or addition operation with
# this object, use the * or + operator instead.
#
# See https://docs.sympy.org/latest/explanation/active-deprecations.html#non-expr-args-deprecated
# for details.
#
# This has been deprecated since SymPy version 1.7. It
# will be removed in a future version of SymPy.
#
#   return Mul(*numer, evaluate=not exact), Mul(*denom, evaluate=not exact)
# Eq(x(t), 807.265053603006*sin(11.5558454962282*t)**2 - 7.53172026967277*sin(32.2501712550246*t)**2 + 807.265053603006*cos(11.5558454962282*t)**2 - 807.265053603009*cos(11.5558454962282*t) - 7.53172026967277*cos(32.2501712550246*t)**2 + 7.53172026967276*cos(32.2501712550246*t))
# Eq(y(t), 0.688153725896098*sin(11.5558454962282*t)**2 - 0.088353725896098*sin(32.2501712550246*t)**2 + 0.688153725896098*cos(11.5558454962282*t)**2 - 0.6881537258961*cos(11.5558454962282*t) - 0.088353725896098*cos(32.2501712550246*t)**2 + 0.0883537258960978*cos(32.2501712550246*t))

# %%
from sympy import *
from sympy.solvers.ode.systems import dsolve_system
x, y = symbols("x y", cls=Function)
t = symbols("t")

k = symbols('k')

T1 = 0.00025 #0.035 m / 140 rad from TSA test
# T1 = symbols("T1") #0.035 m / 140 rad from TSA test
T2 = 3 #guess for leg movement/string contract
m_a = 1/2 * 0.01 * 0.010**2 #cylinder MOI 20g 10mm radius
m_l = 0.1 #mass to push off ground
k = 1000 # no idea honestly

tau_s = 0.1 #N*m stall torque
omega_f = 3000 #about 10,000rpm free speed

eqs = [
    Eq(x(t).diff(t).diff(t), -(T1**2*k/m_a)*x(t) - (T1*k/(T2*m_a))*y(t) + (tau_s - tau_s*x.diff(t)/omega_f)/m_a), 
    Eq(y(t).diff(t).diff(t), (k*T1/(T2*m_l))*x(t) - (k/(T2**2*m_l))*y(t))
]
display(eqs[0], eqs[1])

sol = dsolve_system(eqs, ics={x(0):0, y(0):0, x(t).diff(t).subs(t,0):0, y(t).diff(t).subs(t,0):0})
# sol = dsolve_system(eqs)

xeq = simplify(sol[0][0])
yeq = simplify(sol[0][1])
display(xeq, yeq)
# Out:
# Eq(Derivative(x(t), (t, 2)), -125.0*x(t) - 166666.666666667*y(t) + 199933.333333333)
# Eq(Derivative(y(t), (t, 2)), 0.833333333333333*x(t) - 1111.11111111111*y(t))
# Eq(x(t), 855.760469334588*sin(17.1823235241843*t)**2 - 56.0271360012556*sin(30.673748864809*t)**2 + 855.760469334588*cos(17.1823235241843*t)**2 - 855.760469334588*cos(17.1823235241843*t) - 56.0271360012556*cos(30.673748864809*t)**2 + 56.0271360012557*cos(30.673748864809*t))
# Eq(y(t), 0.874068138265731*sin(17.1823235241843*t)**2 - 0.274268138265732*sin(30.673748864809*t)**2 + 0.874068138265731*cos(17.1823235241843*t)**2 - 0.874068138265731*cos(17.1823235241843*t) - 0.274268138265732*cos(30.673748864809*t)**2 + 0.274268138265732*cos(30.673748864809*t))

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget

# k = 5000

def RK4(f, X, dt):
    # Runge-Kutta 4 integration
    k1,log = f(X)
    k2,_ = f(X + (dt/2)*k1)
    k3,_ = f(X + (dt/2)*k2)
    k4,_ = f(X + dt*k3)
    return X + (dt/6)*(k1 + 2*k2 + 2*k3 + k4), log

def f(X):
    x, xd, y, yd = X
    xdd = -(T1**2*k/m_a)*x - (T1*k/(T2*m_a))*y + (tau_s - tau_s*xd/omega_f)/m_a 
    ydd = (k*T1/(T2*m_l))*x - (k/(T2**2*m_l))*y
    return np.array([xd, xdd, yd, ydd]), T1*T2*x-y

log = [[], [],[], [],[], []] #t, x_anal,y_anal, x_rk4,y_rk4, spring

dt = 0.001
X = np.zeros(4)
for ti in np.arange(0, 0.5, step=dt):
    x_anal = xeq.rhs.subs(t,ti).n()
    y_anal = yeq.rhs.subs(t,ti).n()

    X,spring = RK4(f, X, dt)
    x_rk4, xd_rk4, y_rk4, yd_rk4 = X

    log[0].append(ti)
    log[1].append(x_anal)
    log[2].append(y_anal)
    log[3].append(x_rk4)
    log[4].append(y_rk4)
    log[5].append(spring)

    if(y_rk4 > 0.1):
        break

print(yd_rk4)

plt.close('all')
fig, axs = plt.subplots(2, 1)
axs[0].plot(log[0], log[1], label='act_anal')
# axs[0].plot(log[0], log[3], label='act_rk4')
axs[0].set_ylabel("motor radians")

axs[1].plot(log[0], log[2], label='load_anal')
# axs[1].plot(log[0], log[4], label='load_rk4')
# axs[1].plot(log[0], log[5], label='spring')
axs[1].set_ylabel("meters")


[ax.legend() for ax in axs]
plt.show()
# Out:
# 3.3947601508584606
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ks = np.linspace(500, 5000, 10)
endv = []
for k in ks:

    print(k)


    def f(X):
        x, xd, y, yd = X
        xdd = -(T1**2*k/m_a)*x - (T1*k/(T2*m_a))*y + (tau_s - tau_s*xd/omega_f)/m_a 
        ydd = (k*T1/(T2*m_l))*x - (k/(T2**2*m_l))*y
        return np.array([xd, xdd, yd, ydd]), T1*T2*x-y


    dt = 0.001
    X = np.zeros(4)
    for ti in np.arange(0, 0.5, step=dt):
        # x_anal = xeq.rhs.subs(t,ti).n()
        # y_anal = yeq.rhs.subs(t,ti).n()

        X,spring = RK4(f, X, dt)
        x_rk4, xd_rk4, y_rk4, yd_rk4 = X


        if(y_rk4 > 0.1):
            break
    
    endv.append(yd_rk4)


plt.figure()
plt.plot(ks, endv)
plt.xlabel('ks')
plt.ylabel('endv')
plt.show()
# Out:
# 500.0
# 1000.0
# 1500.0
# 2000.0
# 2500.0
# 3000.0
# 3500.0
# 4000.0
# 4500.0
# 5000.0
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from sympy import *
from sympy.solvers.ode.systems import dsolve_system
x, y = symbols("x y", cls=Function)
t = symbols("t")

c0, c1, c2, c3, c4, c5, c6 = symbols('c:7')

tau_s = 0.1 #N*m stall torque
omega_f = 3000 #about 10,000rpm free speed

eqs = [
    Eq(x(t).diff(t).diff(t), c1*x.diff(t) + c2*x(t) + c3*y(t) + c4), 
    Eq(y(t).diff(t).diff(t), c5*x(t) + c6*y(t))
]
display(eqs[0], eqs[1])

sol = dsolve_system(eqs, ics={x(0):0, y(0):0, x(t).diff(t).subs(t,0):0, y(t).diff(t).subs(t,0):0})
# sol = dsolve_system(eqs)

xeq = simplify(sol[0][0])
yeq = simplify(sol[0][1])
display(xeq, yeq)
# Out:
# Eq(Derivative(x(t), (t, 2)), c1 + c2*x(t) + c3*y(t) + c4)
# Eq(Derivative(y(t), (t, 2)), c5*x(t) + c6*y(t))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[289], line 17
#      11 eqs = [
#      12     Eq(x(t).diff(t).diff(t), c1*x.diff(t) + c2*x(t) + c3*y(t) + c4),
#      13     Eq(y(t).diff(t).diff(t), c5*x(t) + c6*y(t))
#      14 ]
#      15 display(eqs[0], eqs[1])
# ---> 17 sol = dsolve_system(eqs, ics={x(0):0, y(0):0, x(t).diff(t).subs(t,0):0, y(t).diff(t).subs(t,0):0})
#      18 # sol = dsolve_system(eqs)
#      20 xeq = simplify(sol[0][0])
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/solvers/ode/systems.py:2104, in dsolve_system(eqs, funcs, t, ics, doit, simplify)
#    2102 for canon_eq in canon_eqs:
#    2103     try:
# -> 2104         sol = _strong_component_solver(canon_eq, funcs, t)
#    2105     except NotImplementedError:
#    2106         sol = None
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/solvers/ode/systems.py:1709, in _strong_component_solver(eqs, funcs, t)
#    1706 match['t'] = t
#    1708 if match.get('is_higher_order', False):
# -> 1709     sol = _higher_order_ode_solver(match)
#    1711 elif match.get('is_linear', False):
#    1712     sol = _linear_ode_solver(match)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/solvers/ode/systems.py:1655, in _higher_order_ode_solver(match)
#    1653 try:
#    1654     if not is_higher_order_type2:
# -> 1655         sol = _strong_component_solver(new_eqs, new_funcs, t)
#    1656 except NotImplementedError:
#    1657     sol = None
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/solvers/ode/systems.py:1712, in _strong_component_solver(eqs, funcs, t)
#    1709     sol = _higher_order_ode_solver(match)
#    1711 elif match.get('is_linear', False):
# -> 1712     sol = _linear_ode_solver(match)
#    1714 # Note: For now, only linear systems are handled by this function
#    1715 # hence, the match condition is added. This can be removed later.
#    1716 if sol is None and len(eqs) == 1:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/solvers/ode/systems.py:1607, in _linear_ode_solver(match)
#    1604 B = match.get('commutative_antiderivative', None)
#    1605 type = match['type_of_equation']
# -> 1607 sol_vector = linodesolve(A, t, b=rhs, B=B,
#    1608                          type=type, tau=tau)
#    1610 sol = [Eq(f, s) for f, s in zip(funcs, sol_vector)]
#    1612 return sol
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/solvers/ode/systems.py:978, in linodesolve(A, t, b, B, type, doit, tau)
#     976     else:
#     977         Jinv = J.subs(t, -t)
# --> 978         sol_vector = P * J * ((Jinv * P.inv() * b).applyfunc(intx_wrtt) + Cvect)
#     979 else:
#     980     if B is None:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/matrices/matrices.py:2177, in MatrixBase.inv(self, method, iszerofunc, try_block_diag)
#    2176 def inv(self, method=None, iszerofunc=_iszero, try_block_diag=False):
# -> 2177     return _inv(self, method=method, iszerofunc=iszerofunc,
#    2178             try_block_diag=try_block_diag)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/matrices/inverse.py:459, in _inv(M, method, iszerofunc, try_block_diag)
#     456     return diag(*r)
#     458 if method == "GE":
# --> 459     rv = M.inverse_GE(iszerofunc=iszerofunc)
#     460 elif method == "LU":
#     461     rv = M.inverse_LU(iszerofunc=iszerofunc)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/matrices/matrices.py:2162, in MatrixBase.inverse_GE(self, iszerofunc)
#    2161 def inverse_GE(self, iszerofunc=_iszero):
# -> 2162     return _inv_GE(self, iszerofunc=iszerofunc)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/matrices/inverse.py:242, in _inv_GE(M, iszerofunc)
#     239     raise NonSquareMatrixError("A Matrix must be square to invert.")
#     241 big = Matrix.hstack(M.as_mutable(), Matrix.eye(M.rows))
# --> 242 red = big.rref(iszerofunc=iszerofunc, simplify=True)[0]
#     244 if any(iszerofunc(red[j, j]) for j in range(red.rows)):
#     245     raise NonInvertibleMatrixError("Matrix det == 0; not invertible.")
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/matrices/matrices.py:172, in MatrixReductions.rref(self, iszerofunc, simplify, pivots, normalize_last)
#     170 def rref(self, iszerofunc=_iszero, simplify=False, pivots=True,
#     171         normalize_last=True):
# --> 172     return _rref(self, iszerofunc=iszerofunc, simplify=simplify,
#     173         pivots=pivots, normalize_last=normalize_last)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/matrices/reductions.py:320, in _rref(M, iszerofunc, simplify, pivots, normalize_last)
#     247 """Return reduced row-echelon form of matrix and indices of pivot vars.
#     248
#     249 Parameters
#    (...)
#     315 of the matrix, set ``noramlize_last=False``
#     316 """
#     318 simpfunc = simplify if isinstance(simplify, FunctionType) else _simplify
# --> 320 mat, pivot_cols, _ = _row_reduce(M, iszerofunc, simpfunc,
#     321         normalize_last, normalize=True, zero_above=True)
#     323 if pivots:
#     324     mat = (mat, pivot_cols)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/matrices/reductions.py:124, in _row_reduce(M, iszerofunc, simpfunc, normalize_last, normalize, zero_above)
#     121 def _row_reduce(M, iszerofunc, simpfunc, normalize_last=True,
#     122                 normalize=True, zero_above=True):
# --> 124     mat, pivot_cols, swaps = _row_reduce_list(list(M), M.rows, M.cols, M.one,
#     125             iszerofunc, simpfunc, normalize_last=normalize_last,
#     126             normalize=normalize, zero_above=zero_above)
#     128     return M._new(M.rows, M.cols, mat), pivot_cols, swaps
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/matrices/reductions.py:106, in _row_reduce_list(mat, rows, cols, one, iszerofunc, simpfunc, normalize_last, normalize, zero_above)
#     103         if iszerofunc(val):
#     104             continue
# --> 106         cross_cancel(pivot_val, row, val, piv_row)
#     107     piv_row += 1
#     109 # normalize each row
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/matrices/reductions.py:55, in _row_reduce_list.<locals>.cross_cancel(a, i, b, j)
#      53 q = (j - i)*cols
#      54 for p in range(i*cols, (i + 1)*cols):
# ---> 55     mat[p] = isimp(a*mat[p] - b*mat[p + q])
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/matrices/utilities.py:27, in _dotprodsimp(expr, withsimp)
#      25 """Wrapper for simplify.dotprodsimp to avoid circular imports."""
#      26 from sympy.simplify.simplify import dotprodsimp as dps
# ---> 27 return dps(expr, withsimp=withsimp)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/simplify/simplify.py:2099, in dotprodsimp(expr, withsimp)
#    2096 expr2   = nonalg_subs_dummies(expr, dummies)
#    2098 if expr2 is expr or count_ops_alg(expr2)[0] >= 6: # check again after substitution
# -> 2099     expr3 = cancel(expr2)
#    2101     if expr3 != expr2:
#    2102         expr       = expr3.subs([(d, e) for e, d in dummies.items()])
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/polys/polytools.py:6890, in cancel(f, _signsimp, *gens, **args)
#    6887                 pass
#    6888         return f.xreplace(dict(reps))
# -> 6890 c, (P, Q) = 1, F.cancel(G)
#    6891 if opt.get('polys', False) and 'gens' not in opt:
#    6892     opt['gens'] = R.symbols
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/polys/rings.py:2242, in PolyElement.cancel(self, g)
#    2239 domain = ring.domain
#    2241 if not (domain.is_Field and domain.has_assoc_Ring):
# -> 2242     _, p, q = f.cofactors(g)
#    2243 else:
#    2244     new_ring = ring.clone(domain=domain.get_ring())
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/polys/rings.py:2158, in PolyElement.cofactors(f, g)
#    2155     return h, cff, cfg
#    2157 J, (f, g) = f.deflate(g)
# -> 2158 h, cff, cfg = f._gcd(g)
#    2160 return (h.inflate(J), cff.inflate(J), cfg.inflate(J))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/polys/rings.py:2191, in PolyElement._gcd(f, g)
#    2189     return f._gcd_QQ(g)
#    2190 elif ring.domain.is_ZZ:
# -> 2191     return f._gcd_ZZ(g)
#    2192 else: # TODO: don't use dense representation (port PRS algorithms)
#    2193     return ring.dmp_inner_gcd(f, g)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/polys/rings.py:2196, in PolyElement._gcd_ZZ(f, g)
#    2195 def _gcd_ZZ(f, g):
# -> 2196     return heugcd(f, g)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/polys/heuristicgcd.py:80, in heugcd(f, g)
#      78     h, cff, cfg = domain.cofactors(ff, gg)
#      79 else:
# ---> 80     h, cff, cfg = heugcd(ff, gg)
#      82 h = _gcd_interpolate(h, x, ring)
#      83 h = h.primitive()[1]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/polys/heuristicgcd.py:80, in heugcd(f, g)
#      78     h, cff, cfg = domain.cofactors(ff, gg)
#      79 else:
# ---> 80     h, cff, cfg = heugcd(ff, gg)
#      82 h = _gcd_interpolate(h, x, ring)
#      83 h = h.primitive()[1]
#
#     [... skipping similar frames: heugcd at line 80 (1 times)]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/polys/heuristicgcd.py:80, in heugcd(f, g)
#      78     h, cff, cfg = domain.cofactors(ff, gg)
#      79 else:
# ---> 80     h, cff, cfg = heugcd(ff, gg)
#      82 h = _gcd_interpolate(h, x, ring)
#      83 h = h.primitive()[1]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/polys/heuristicgcd.py:61, in heugcd(f, g)
#      58 x0 = ring.gens[0]
#      59 domain = ring.domain
# ---> 61 gcd, f, g = f.extract_ground(g)
#      63 f_norm = f.max_norm()
#      64 g_norm = g.max_norm()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/polys/rings.py:2056, in PolyElement.extract_ground(self, g)
#    2054 def extract_ground(self, g):
#    2055     f = self
# -> 2056     fc = f.content()
#    2057     gc = g.content()
#    2059     gcd = f.ring.domain.gcd(fc, gc)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/polys/rings.py:1963, in PolyElement.content(f)
#    1960 gcd = domain.gcd
#    1962 for coeff in f.itercoeffs():
# -> 1963     cont = gcd(cont, coeff)
#    1965 return cont
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sympy/polys/domains/integerring.py:216, in IntegerRing.gcd(self, a, b)
#     214 def gcd(self, a, b):
#     215     """Compute GCD of ``a`` and ``b``. """
# --> 216     return gcd(a, b)
#
# KeyboardInterrupt:
