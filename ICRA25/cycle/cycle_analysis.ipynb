# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib widget

# %%
df = pd.read_csv('cycle_data.csv')
df
# Out:
#            t         x          y
# 0   0.000000  145.2652   22.16110
# 1   0.034841  148.5457   21.25053
# 2   0.069683  153.4604   16.28609
# 3   0.104524  164.2949   15.76919
# 4   0.139365  171.4410   16.21107
# ..       ...       ...        ...
# 78  2.717624  108.6634 -174.84430
# 79  2.752465  108.3946 -175.02450
# 80  2.787306  107.4209 -175.02300
# 81  2.822148  107.6619 -174.91040
# 82  2.856989  108.0025 -174.57220
#
# [83 rows x 3 columns]

# %%
# plt.figure()
plt.figure(figsize=(8,3))
plt.gca().set_aspect('equal', adjustable='box')
plt.plot(df['x'], df['y'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
