# %%
import casadi
from numpy import pi
import numpy as np

opti = casadi.Opti()

sin2 = opti.variable()
cos2 = opti.variable()
sin3 = opti.variable()
cos3 = opti.variable()

L1, L2, L3, L4, theta1 = (1, 2.5, 2.5, 2, 5/4*pi)
sin1, cos1 = (np.sin(theta1), np.cos(theta1))

opti.minimize(  (L1*sin1 + L2*sin2 + L3*sin3)**2 + (L1*cos1 + L2*cos2 + L3*cos3 - L4)**2)
opti.subject_to( sin2**2 + cos2**2==1 )
opti.subject_to( sin3**2 + cos3**2==1 )
# opti.subject_to(       x+y>=1 )

        # L1*sin1 + L2*sin2 + L3*sin3,
        # L1*cos1 + L2*cos2 + L3*cos3 - L4, 
        # sin2**2 + cos2**2 - 1,
        # sin3**2 + cos3**2 - 1,    


# (L1*sin1 + L2*sin2 + L3*sin3)**2 + (L1*cos1 + L2*cos2 + L3*cos3 - L4)**2 + (sin2**2 + cos2**2 - 1)**2 + (sin3**2 + cos3**2 - 1)**2


opti.solver('ipopt')


sol = opti.solve()

print(sol.value(sin2), sol.value(cos2), sol.value(sin3), sol.value(cos3))

sol.value((L1*sin1 + L2*sin2 + L3*sin3)**2 + (L1*cos1 + L2*cos2 + L3*cos3 - L4)**2)
# Out:
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        4
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:        6
#
# Total number of variables............................:        4
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        2
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  7.8284271e+00 1.00e+00 1.35e+01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.2515469e-06 6.87e-01 1.92e+08  -1.0 5.41e-01  -2.0 1.00e+00 1.00e+00f  1
#    2  9.4239523e+00 3.77e-01 8.27e+09  -1.0 5.94e-01   9.8 1.00e+00 1.00e+00h  1
#    3  5.1358196e+00 2.58e-02 1.52e+09  -1.0 1.56e-01  10.3 1.00e+00 1.00e+00f  1
#    4  4.8508912e+00 1.63e-04 1.89e+07  -1.0 1.23e-02    -  1.00e+00 1.00e+00f  1
#    5  4.8491007e+00 6.61e-09 1.54e+03  -1.0 7.87e-05    -  1.00e+00 1.00e+00h  1
#    6  4.8491006e+00 2.22e-16 5.09e-06  -1.0 3.20e-09    -  1.00e+00 1.00e+00h  1
#    7  4.8491006e+00 0.00e+00 6.67e-07  -8.6 1.07e-16   9.8 1.00e+00 1.00e+00   0
#    8  4.8491006e+00 0.00e+00 2.40e-13  -8.6 1.16e-22   9.3 1.00e+00 1.00e+00T  0
#
# Number of Iterations....: 8
#
#                                    (scaled)                 (unscaled)
# Objective...............:   4.8491006054280570e+00    4.8491006054280570e+00
# Dual infeasibility......:   2.4025226252888388e-13    2.4025226252888388e-13
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   0.0000000000000000e+00    0.0000000000000000e+00
# Overall NLP error.......:   2.4025226252888388e-13    2.4025226252888388e-13
#
#
# Number of objective function evaluations             = 9
# Number of objective gradient evaluations             = 9
# Number of equality constraint evaluations            = 9
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 9
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 8
# Total seconds in IPOPT                               = 0.005
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  22.00us (  2.44us)  15.37us (  1.71us)         9
#        nlp_g  |  19.00us (  2.11us)  14.71us (  1.63us)         9
#   nlp_grad_f  |  66.00us (  6.60us)  24.33us (  2.43us)        10
#   nlp_hess_l  |  29.00us (  3.63us)  28.75us (  3.59us)         8
#    nlp_jac_g  |  24.00us (  2.40us)  21.75us (  2.17us)        10
#        total  |   5.78ms (  5.78ms)   5.32ms (  5.32ms)         1
# 0.25272473256218997 0.967538221235404 0.25272473256223354 0.9675382212353926
# 4.849100605428057

# %%
from casadi import *
opti = Opti()

x = opti.variable()
y = opti.variable()
A = MX(2,1)
A = [x, y]

opti.minimize(-A[0]*A[1])
opti.subject_to(opti.bounded(0, x+y, 10))

opti.solver('ipopt')
sol = opti.solve()

print(sol.value(x), sol.value(y))


# z = MX([x[0],2])
# z
# z = if_else(x > 0, SX([sqrt(x), 0]), SX([0, sqrt(-x)]))
# cos_z = (SX([z[0]*sin(z[1]),  z[0]*cos(z[1])]) + SX([z[0]*sin(z[1]),  -z[0]*cos(z[1])])) / 2
# cos_z
# Out:
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        2
# Number of nonzeros in Lagrangian Hessian.............:        1
#
# Total number of variables............................:        2
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        1
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        1
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0 -0.0000000e+00 0.00e+00 0.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1 -3.0443465e-03 0.00e+00 2.41e-03  -1.0 1.00e-01    -  9.56e-01 1.00e+00f  1
#    2 -2.6248009e-02 0.00e+00 2.14e-01  -1.7 2.14e-01   0.0 1.00e+00 1.00e+00f  1
#    3 -1.4723536e-01 0.00e+00 3.09e-01  -1.7 4.43e-01  -0.5 4.98e-01 1.00e+00f  1
#    4 -3.9384541e-01 0.00e+00 4.34e-01  -1.7 4.88e-01  -0.1 1.00e+00 1.00e+00f  1
#    5 -5.3554338e-01 0.00e+00 4.94e-01  -1.7 2.08e-01   0.4 1.00e+00 1.00e+00f  1
#    6 -1.6067747e+00 0.00e+00 8.47e-01  -1.7 1.07e+00  -0.1 1.00e+00 1.00e+00f  1
#    7 -2.2697794e+00 0.00e+00 1.01e+00  -1.7 4.78e-01   0.3 1.00e+00 1.00e+00f  1
#    8 -8.2042260e+00 0.00e+00 1.91e+00  -1.7 2.72e+00  -0.2 1.00e+00 1.00e+00f  1
#    9 -1.2137810e+01 0.00e+00 2.32e+00  -1.7 1.24e+00   0.3 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10 -2.4848624e+01 0.00e+00 3.31e+00  -1.7 7.93e+00  -0.2 7.64e-01 3.79e-01f  1
#   11 -2.4998484e+01 0.00e+00 2.42e+01  -1.7 4.51e+01    -  1.00e+00 6.66e-04f  1
#   12 -2.4995126e+01 0.00e+00 0.00e+00  -1.7 6.72e-04    -  1.00e+00 1.00e+00f  1
#   13 -2.4999849e+01 0.00e+00 0.00e+00  -3.8 9.45e-04    -  1.00e+00 1.00e+00f  1
#   14 -2.4999999e+01 0.00e+00 0.00e+00  -5.7 3.00e-05    -  1.00e+00 1.00e+00f  1
#   15 -2.5000000e+01 0.00e+00 0.00e+00  -8.6 3.68e-07    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 15
#
#                                    (scaled)                 (unscaled)
# Objective...............:  -2.5000000497494092e+01   -2.5000000497494092e+01
# Dual infeasibility......:   0.0000000000000000e+00    0.0000000000000000e+00
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.5059066184009957e-09    2.5059066184009957e-09
# Overall NLP error.......:   2.5059066184009957e-09    2.5059066184009957e-09
#
#
# Number of objective function evaluations             = 16
# Number of objective gradient evaluations             = 16
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 16
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 16
# Number of Lagrangian Hessian evaluations             = 15
# Total seconds in IPOPT                               = 0.004
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |  17.00us (  1.06us)   9.33us (583.13ns)        16
#        nlp_g  |  21.00us (  1.31us)  10.54us (658.75ns)        16
#   nlp_grad_f  |  13.00us (764.71ns)  12.83us (755.00ns)        17
#   nlp_hess_l  |   9.00us (600.00ns)  12.13us (808.53ns)        15
#    nlp_jac_g  |  11.00us (647.06ns)  12.37us (727.88ns)        17
#        total  |   4.51ms (  4.51ms)   4.37ms (  4.37ms)         1
# 5.000000049749409 5.000000049749409
